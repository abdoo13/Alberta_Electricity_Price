# %% [markdown]
# ## **1 - Importing Libraries & Utilities**

# %%
from google.colab import files
import pandas as pd
import numpy as np
import os
from IPython.display import clear_output
from time import sleep, perf_counter
from datetime import timedelta
from google.colab import files, drive
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %% [markdown]
# ## **2 - Uploading Required Data Files**

# %%
drive.mount('/content/drive')
path_files = '/content/drive/MyDrive/2023_DSMP_Project'
# Out:
# Mounted at /content/drive

# %%
for file_name in sorted(os.listdir(path_files)):
  if '.xlsx' in file_name:
    print(file_name)
# Out:
# 0 - Macro Indicators.xlsx
# 1 - Benchmark Prices.xlsx
# 2 - End - Use Prices.xlsx
# 3 - End - Use Demand.xlsx
# 4 - Primary Energy Demand.xlsx
# 5 - Electricity Generation.xlsx
# 6 - Electricity Capacity.xlsx
# 7 - Electricity Interchange.xlsx
# 8 - Weather_Data_Alberta_WU.xlsx
# Alberta_EP_Monthly.xlsx
# DSMP_Weather_Data_Canada.xlsx
# Economics_Alberta.xlsx

# %% [markdown]
# ### **2.1 - Joining Data Files - 2 & 3**

# %%
for j in range(2,4):
  print(sorted(os.listdir(path_files))[j])
  df = pd.read_excel(path_files + '/' + sorted(os.listdir(path_files))[j])
  globals()[f"df_{j}"] = df
  del df
# Out:
# 2 - End - Use Prices.xlsx
# 3 - End - Use Demand.xlsx

# %%
# Joining df_2 and df_3
df_2_3 = df_2.merge(df_3, on = df_2.columns.tolist()[:4], how = 'outer')
del df_2, df_3
df_2_3.rename(columns = {'Price (2022 CAD $ per GJ)':'Price (CAD $/GJ)'}, inplace = True)
#
#df_0 = pd.read_excel(path_files + '/' +'0 - Macro Indicators.xlsx')
#df_2_3 = df_2_3.merge(df_0, on = ['Scenario', 'Year'], how = 'outer')
#df_2_3 = df2_3[(df_2_3['Value']!='Population (thousands)') & (df_2_3['Value']!='Population (thousands)')]
df_2_3
# Out:
#               Scenario       Sector                     Region  Year  \
# 0      Global Net-zero  Residential  Newfoundland and Labrador  2005
# 1      Global Net-zero  Residential       Prince Edward Island  2005
# 2      Global Net-zero  Residential                Nova Scotia  2005
# 3      Global Net-zero  Residential              New Brunswick  2005
# 4      Global Net-zero  Residential                     Quebec  2005
# ...                ...          ...                        ...   ...
# 5377  Current Measures   Industrial                    Alberta  2050
# 5378  Current Measures   Industrial           British Columbia  2050
# 5379  Current Measures   Industrial                      Yukon  2050
# 5380  Current Measures   Industrial      Northwest Territories  2050
# 5381  Current Measures   Industrial                    Nunavut  2050
#
#       Price (CAD $/GJ)  End-Use Demand (PetaJoules)  \
# 0                37.59                        12.17
# 1                45.86                         0.58
# 2                41.17                        14.86
# 3                39.36                        19.86
# 4                25.46                       206.31
# ...                ...                          ...
# 5377             56.17                       249.90
# 5378             32.28                       166.62
# 5379             57.38                         0.11
# 5380             41.94                         0.08
# 5381             60.10                         0.49
#
#       GHG Emmisions (KTons_CO2_Equivalent)
# 0                                21.501038
# 1                                 9.204189
# 2                                21.941681
# 3                                23.646266
# 4                                18.720960
# ...                                    ...
# 5377                              3.680523
# 5378                              2.679146
# 5379                              0.298651
# 5380                              0.324334
# 5381                              2.070485
#
# [5382 rows x 7 columns]

# %% [markdown]
# ### **2.2 - Joining Data Files - 5 & 6**

# %%
for j in range(5,7):
  print(sorted(os.listdir(path_files))[j])
  df = pd.read_excel(path_files + '/' + sorted(os.listdir(path_files))[j])
  globals()[f"df_{j}"] = df
  del df
# Out:
# 5 - Electricity Generation.xlsx
# 6 - Electricity Capacity.xlsx

# %% [markdown]
# According to the [U.S. Energy Information Administration (EIA)](https://www.eia.gov/tools/faqs/faq.php?id=101&t=3):
# - **Electricity Generation** is the amount of electricity a generator produces during a specific period of time.
# - **Electricity Capacity** is the maximum electric output an electricity generator can produce under specific conditions.

# %%
df_5_6 = df_5.merge(df_6, on = df_5.columns.tolist()[:4], how = 'outer')
del df_5, df_6
scenario_list = list(df_5_6['Scenario'].unique())
region_list = list(df_5_6['Region'].unique())
#df_5_6[(df_5_6['Scenario'] == 'Global Net-zero') & (df_5_6['Region'] == 'Newfoundland and Labrador')].head(15)

# %%
sources_ = df_5_6['Sources'].unique().tolist()
#
df_5_6['Sources'] = df_5_6['Sources'].apply(lambda x: 'Renewable Energies_Biomass' if x in sources_[:4] else "Nuclear" if x == 'Uranium'	else "Refined Petroleum Products_Oil" if x == "Oil" else 'Coal, Coke and Coke Oven Gas' if x == 'Coal & Coke' else x)
#
df_5_6 = df_5_6.groupby(by = df_5_6.columns.tolist()[:4]).sum()
df_5_6 = df_5_6.reset_index().sort_values('Year')
#df_5_6[(df_5_6['Scenario'] == 'Global Net-zero') & (df_5_6['Region'] == 'Newfoundland and Labrador') & (df_5_6['Sources'] == 'Renewable Energies')]
#df_5_6
df_5_6["Scenario"] = pd.Categorical(df_5_6["Scenario"], categories = scenario_list)
#
df_5_6["Region"] = pd.Categorical(df_5_6["Region"], categories = region_list)
#
df_5_6.sort_values(by = ["Scenario","Region"])
# Out:
#               Scenario                     Region  \
# 6900   Global Net-zero  Newfoundland and Labrador
# 7084   Global Net-zero  Newfoundland and Labrador
# 7038   Global Net-zero  Newfoundland and Labrador
# 6992   Global Net-zero  Newfoundland and Labrador
# 6946   Global Net-zero  Newfoundland and Labrador
# ...                ...                        ...
# 4829  Current Measures                    Nunavut
# 4783  Current Measures                    Nunavut
# 4737  Current Measures                    Nunavut
# 4691  Current Measures                    Nunavut
# 4645  Current Measures                    Nunavut
#
#                              Sources  Year  Electricity Generation - (GWh)  \
# 6900    Coal, Coke and Coke Oven Gas  2005                            0.00
# 7084      Renewable Energies_Biomass  2005                        40741.37
# 7038  Refined Petroleum Products_Oil  2005                         1306.21
# 6992                         Nuclear  2005                            0.00
# 6946                     Natural Gas  2005                          267.07
# ...                              ...   ...                             ...
# 4829      Renewable Energies_Biomass  2050                          332.81
# 4783  Refined Petroleum Products_Oil  2050                           85.73
# 4737                         Nuclear  2050                            0.00
# 4691                     Natural Gas  2050                            0.00
# 4645    Coal, Coke and Coke Oven Gas  2050                            0.00
#
#       Electricity Capacity - (GWh)
# 6900                          0.00
# 7084                       6805.68
# 7038                        783.70
# 6992                          0.00
# 6946                        131.50
# ...                            ...
# 4829                        102.89
# 4783                         70.28
# 4737                          0.00
# 4691                          0.00
# 4645                          0.00
#
# [8970 rows x 6 columns]

# %% [markdown]
# ### **2.3 - Joining Data Files - 4 and 5_6**

# %%
j = 4
print(sorted(os.listdir(path_files))[j])
df_4 = pd.read_excel(path_files + '/' + sorted(os.listdir(path_files))[j])
df_4['Sources'] = df_4['Sources'].apply(lambda x: 'Renewable Energies_Biomass' if x in ['Hydro', 'Other Renewables and Landfill Gas'] else "Refined Petroleum Products_Oil" if x == 'Refined Petroleum Products' else x)
#df_4
# Out:
# 4 - Primary Energy Demand.xlsx

# %%
df_4 = df_4.groupby(by = df_4.columns.tolist()[:4]).sum()
df_4 = df_4.reset_index().sort_values('Year')
df_4["Scenario"] = pd.Categorical(df_4["Scenario"], categories = scenario_list)
#
df_4["Region"] = pd.Categorical(df_4["Region"], categories = region_list)
#
#df_4.sort_values(by = ["Scenario","Region"]).head(10)
#
# Joining df_4 and df_5_6
df_4 = df_4.merge(df_5_6, on = df_4.columns.tolist()[:4], how = 'outer')
del df_5_6
df_4["Scenario"] = pd.Categorical(df_4["Scenario"], categories = scenario_list)
#
df_4["Region"] = pd.Categorical(df_4["Region"], categories = region_list)
df_4
# Out:
#               Scenario                Region                         Sources  \
# 0      Canada Net-zero               Alberta    Coal, Coke and Coke Oven Gas
# 1      Global Net-zero  Prince Edward Island    Coal, Coke and Coke Oven Gas
# 2     Current Measures               Nunavut                     Natural Gas
# 3      Global Net-zero         New Brunswick      Renewable Energies_Biomass
# 4      Global Net-zero              Manitoba    Coal, Coke and Coke Oven Gas
# ...                ...                   ...                             ...
# 8965   Canada Net-zero  Prince Edward Island                         Nuclear
# 8966   Global Net-zero              Manitoba  Refined Petroleum Products_Oil
# 8967   Canada Net-zero  Prince Edward Island  Refined Petroleum Products_Oil
# 8968   Canada Net-zero                 Yukon      Renewable Energies_Biomass
# 8969   Global Net-zero                 Yukon      Renewable Energies_Biomass
#
#       Year  Primary Demand - Petajoules  Electricity Generation - (GWh)  \
# 0     2005                       547.86                        43581.07
# 1     2005                         0.00                            0.00
# 2     2005                         0.00                            0.00
# 3     2005                        64.22                         4485.00
# 4     2005                         2.79                          413.26
# ...    ...                          ...                             ...
# 8965  2050                        31.45                         3299.12
# 8966  2050                        37.90                            3.79
# 8967  2050                         3.17                            0.16
# 8968  2050                         3.03                          605.95
# 8969  2050                         2.83                          592.44
#
#       Electricity Capacity - (GWh)
# 0                          5696.00
# 1                             0.00
# 2                             0.00
# 3                          1080.50
# 4                            97.64
# ...                            ...
# 8965                        457.16
# 8966                         37.31
# 8967                         40.45
# 8968                        225.24
# 8969                        221.23
#
# [8970 rows x 7 columns]

# %% [markdown]
# ### **2.4 - Joining Data Files - 4 and 7**

# %%
j = 7
print(sorted(os.listdir(path_files))[j])
df_7 = pd.read_excel(path_files + '/' + sorted(os.listdir(path_files))[j])
# Let's delete some unuseful "Interchange Flows" categroies
Interchange_Flows = [flow for flow in df_7['Interchange Flows'].unique().tolist() if 'Net' not in flow]
df_7 = df_7[df_7['Interchange Flows'].isin(Interchange_Flows)]
# Joining df_4 and df_5_6
df_4 = df_4.merge(df_7, on = ['Scenario',	'Region',	'Year'], how = 'outer')
del df_7
#
df_4["Scenario"] = pd.Categorical(df_4["Scenario"], categories = scenario_list)
#
df_4["Region"] = pd.Categorical(df_4["Region"], categories = region_list)
df_4.sort_values(by = ["Scenario","Region"], inplace = True, ignore_index = True)
df_4
# Out:
# 7 - Electricity Interchange.xlsx
#                Scenario                     Region  \
# 0       Global Net-zero  Newfoundland and Labrador
# 1       Global Net-zero  Newfoundland and Labrador
# 2       Global Net-zero  Newfoundland and Labrador
# 3       Global Net-zero  Newfoundland and Labrador
# 4       Global Net-zero  Newfoundland and Labrador
# ...                 ...                        ...
# 35875  Current Measures                    Nunavut
# 35876  Current Measures                    Nunavut
# 35877  Current Measures                    Nunavut
# 35878  Current Measures                    Nunavut
# 35879  Current Measures                    Nunavut
#
#                             Sources  Year  Primary Demand - Petajoules  \
# 0      Coal, Coke and Coke Oven Gas  2005                         3.11
# 1      Coal, Coke and Coke Oven Gas  2005                         3.11
# 2      Coal, Coke and Coke Oven Gas  2005                         3.11
# 3      Coal, Coke and Coke Oven Gas  2005                         3.11
# 4        Renewable Energies_Biomass  2005                       162.02
# ...                             ...   ...                          ...
# 35875                   Natural Gas  2050                         0.00
# 35876  Coal, Coke and Coke Oven Gas  2050                         0.00
# 35877  Coal, Coke and Coke Oven Gas  2050                         0.00
# 35878  Coal, Coke and Coke Oven Gas  2050                         0.00
# 35879  Coal, Coke and Coke Oven Gas  2050                         0.00
#
#        Electricity Generation - (GWh)  Electricity Capacity - (GWh)  \
# 0                                0.00                          0.00
# 1                                0.00                          0.00
# 2                                0.00                          0.00
# 3                                0.00                          0.00
# 4                            40741.37                       6805.68
# ...                               ...                           ...
# 35875                            0.00                          0.00
# 35876                            0.00                          0.00
# 35877                            0.00                          0.00
# 35878                            0.00                          0.00
# 35879                            0.00                          0.00
#
#                Interchange Flows  Interchange (GWh)
# 0       Interprovincial In-Flows              15.69
# 1      Interprovincial Out-Flows           30204.72
# 2                        Exports               0.00
# 3                        Imports               0.00
# 4       Interprovincial In-Flows              15.69
# ...                          ...                ...
# 35875                    Imports               0.00
# 35876   Interprovincial In-Flows               0.00
# 35877  Interprovincial Out-Flows               0.00
# 35878                    Exports               0.00
# 35879                    Imports               0.00
#
# [35880 rows x 9 columns]

# %% [markdown]
# According to the **Michigan Public Service Comminsion** (**MSPC**):
#
# “**Inflow**” means the electricity a customer uses from the utility distribution system. “**Outflow**” means the electricity
# generated by the customer’s distributed generation project that is not used on-site and is instead sent to the electric
# grid.
#
# **Courtesy:**
#
# https://www.michigan.gov/-/media/Project/Websites/mpsc/consumer/info/briefs/Distributed_Generation_Issue_Brief_4-18-18.pdf?rev=3bcf2592c5a64f328220811750e35496#:~:text=%E2%80%9CInflow%E2%80%9D%20means%20the%20electricity%20a,sent%20to%20the%20electric%20grid.

# %% [markdown]
# ### **2.5 - Joining Data Files - 2_3 and 4 DataFrames**

# %%
df = df_4.merge(df_2_3, on = ['Scenario',	'Region',	'Year'], how = 'outer')
cols = df.columns.tolist()
new_cols = cols[:-3] + cols[-2:] + [cols[-3]]
df = df[new_cols]
df.head(5)
# Out:
#           Scenario                     Region                       Sources  \
# 0  Global Net-zero  Newfoundland and Labrador  Coal, Coke and Coke Oven Gas
# 1  Global Net-zero  Newfoundland and Labrador  Coal, Coke and Coke Oven Gas
# 2  Global Net-zero  Newfoundland and Labrador  Coal, Coke and Coke Oven Gas
# 3  Global Net-zero  Newfoundland and Labrador  Coal, Coke and Coke Oven Gas
# 4  Global Net-zero  Newfoundland and Labrador  Coal, Coke and Coke Oven Gas
#
#    Year  Primary Demand - Petajoules  Electricity Generation - (GWh)  \
# 0  2005                         3.11                             0.0
# 1  2005                         3.11                             0.0
# 2  2005                         3.11                             0.0
# 3  2005                         3.11                             0.0
# 4  2005                         3.11                             0.0
#
#    Electricity Capacity - (GWh)          Interchange Flows  Interchange (GWh)  \
# 0                           0.0   Interprovincial In-Flows              15.69
# 1                           0.0   Interprovincial In-Flows              15.69
# 2                           0.0   Interprovincial In-Flows              15.69
# 3                           0.0  Interprovincial Out-Flows           30204.72
# 4                           0.0  Interprovincial Out-Flows           30204.72
#
#         Sector  End-Use Demand (PetaJoules)  \
# 0  Residential                        12.17
# 1   Commercial                         7.72
# 2   Industrial                        15.68
# 3  Residential                        12.17
# 4   Commercial                         7.72
#
#    GHG Emmisions (KTons_CO2_Equivalent)  Price (CAD $/GJ)
# 0                             21.501038             37.59
# 1                             13.639113             29.12
# 2                             27.702241             21.27
# 3                             21.501038             37.59
# 4                             13.639113             29.12

# %% [markdown]
# ### **2.6 - Post-Processing**

# %%
df.loc[df['Sources']=='Renewable Energies_Biomass', 'GHG Emmisions (KTons_CO2_Equivalent)'] = 0
#
df.loc[(df['Sources']=='Nuclear'), 'GHG Emmisions (KTons_CO2_Equivalent)'] = 0
df.loc[(df['Sources']=='Nuclear') & (df['Electricity Capacity - (GWh)']==0), 'Interchange (GWh)'] = 0
df.loc[(df['Sources']=='Nuclear') & (df['Electricity Capacity - (GWh)']==0), 'Price (CAD $/GJ)'] = 0

# %% [markdown]
# ## **3 - Integrating Weather Data**

# %% [markdown]
# ### **3.1 - Subsetting Alberta's DataFrame**

# %%
data = df[df['Region'] == 'Alberta'].reset_index(drop = True)
data.drop(['Region'], axis = 1, inplace = True)
data.head(5)
# Out:
#           Scenario                       Sources  Year  \
# 0  Global Net-zero  Coal, Coke and Coke Oven Gas  2005
# 1  Global Net-zero  Coal, Coke and Coke Oven Gas  2005
# 2  Global Net-zero  Coal, Coke and Coke Oven Gas  2005
# 3  Global Net-zero  Coal, Coke and Coke Oven Gas  2005
# 4  Global Net-zero  Coal, Coke and Coke Oven Gas  2005
#
#    Primary Demand - Petajoules  Electricity Generation - (GWh)  \
# 0                       547.86                        43581.07
# 1                       547.86                        43581.07
# 2                       547.86                        43581.07
# 3                       547.86                        43581.07
# 4                       547.86                        43581.07
#
#    Electricity Capacity - (GWh)          Interchange Flows  Interchange (GWh)  \
# 0                        5696.0   Interprovincial In-Flows            1740.06
# 1                        5696.0   Interprovincial In-Flows            1740.06
# 2                        5696.0   Interprovincial In-Flows            1740.06
# 3                        5696.0  Interprovincial Out-Flows            1198.17
# 4                        5696.0  Interprovincial Out-Flows            1198.17
#
#         Sector  End-Use Demand (PetaJoules)  \
# 0  Residential                        27.97
# 1   Commercial                        45.73
# 2   Industrial                       137.60
# 3  Residential                        27.97
# 4   Commercial                        45.73
#
#    GHG Emmisions (KTons_CO2_Equivalent)  Price (CAD $/GJ)
# 0                              8.318513             33.21
# 1                             13.600485             26.44
# 2                             40.923394             21.92
# 3                              8.318513             33.21
# 4                             13.600485             26.44

# %% [markdown]
# ### **3.2 - Integrating MacroEconomic Data**

# %%
macro_econom = pd.read_excel(path_files + '/' + 'Economics_Alberta.xlsx', sheet_name='Macro_Econom')
macro_econom = macro_econom.iloc[:,:-1]
#macro_econom['Time'] = pd.to_datetime(macro_econom['Time']).dt.to_period('D')
#macro_econom.head(5)
data = data.merge(macro_econom.iloc[:,:-1], on = 'Year', how = 'outer')
#
last_column = data.pop('Price (CAD $/GJ)')
data.insert(data.shape[1], 'Price (CAD $/GJ)', last_column)
#data

# %%
data['Year'] = pd.to_datetime(data['Year'], format = '%Y')
data.rename(columns = {'Year':'Time'}, inplace = True)
#
data['Time'] = data['Time'].apply(lambda x: x - np.timedelta64(1, 'M')) #'M'
data['Time'] = data['Time'].dt.to_period('D') # 'M'
#
data = data[data['Time']<'2024-01-01']
data.reset_index(inplace = True, drop = True)
#data

# %% [markdown]
# data.to_excel('data.xlsx', index = False, freeze_panes = (1,0))
# files.download('data.xlsx')

# %% [markdown]
# ### **3.3 - Uploading Alberta's Weather Data**

# %%
wu_data = pd.read_excel(path_files + '/' + '8 - Weather_Data_Alberta_WU.xlsx')
print(sorted(os.listdir(path_files))[-4])
#
wu = wu_data#.groupby(pd.Grouper(key = 'Time', axis = 0, freq = 'M')).mean() # ======> Delete "#" at "#.groupby" when grouping on a monthly basis
#wu.reset_index(inplace = True)          # ======> # Activate this when working on a monthly basis
#wu['Time'] = wu['Time'].dt.to_period('M')         # Activate this when working on a monthly basis
wu = wu[wu['Time']>= '2004-12-31']               # Deactivate this when working on a monthly basis
wu.reset_index(inplace = True, drop = True)      #       "      "    "     "     " "    "      "
wu.drop(['Region'], axis = 1, inplace = True)    #       "      "    "     "     " "    "      "
wu['Time'] = wu['Time'].dt.to_period('D')        #       "      "    "     "     " "    "      "
wu
# Out:
# DSMP_Weather_Data_Canada.xlsx
#             Time  Temp_Max (°F)  Temp_Avg (°F)  Temp_Min (°F)  Hum_Max (%)  \
# 0     2004-12-31              0           -8.9            -18           77
# 1     2005-01-01              0           -3.7            -11           77
# 2     2005-01-02              0          -13.3            -24           77
# 3     2005-01-03              0           -8.6            -26           91
# 4     2005-01-04              3           -7.5            -20           85
# ...          ...            ...            ...            ...          ...
# 6935  2023-12-27             36           24.0             12           80
# 6936  2023-12-28             46           29.6             18           86
# 6937  2023-12-29             37           25.2             14           93
# 6938  2023-12-30             37           29.0             23           93
# 6939  2023-12-31             43           31.4             16          100
#
#       Hum_Avg (%)  Hum_Min (%)  Wind_Speed_Max (mph)  Wind_Speed_Avg (mph)  \
# 0            58.5            0                    12                   4.6
# 1            58.5            0                     9                   5.0
# 2            61.9            0                     7                   4.0
# 3            51.7            0                     7                   2.5
# 4            69.2            0                    16                   8.6
# ...           ...          ...                   ...                   ...
# 6935         68.7           52                    16                   8.9
# 6936         71.7           49                    10                   5.5
# 6937         76.0           60                    12                   5.3
# 6938         78.8           65                    18                  11.0
# 6939         83.8           61                     8                   4.2
#
#       Wind_Speed_Min (mph)
# 0                        0
# 1                        0
# 2                        2
# 3                        0
# 4                        0
# ...                    ...
# 6935                     0
# 6936                     0
# 6937                     0
# 6938                     6
# 6939                     0
#
# [6940 rows x 10 columns]

# %% [markdown]
# ### **3.4 - Expanding Alberta's Dataset - Monthly Basis**

# %%
sample = data[data['Time']<='2004-12-31'].select_dtypes(include='O')
sample.reset_index(drop = True, inplace = True)

# %%
temp = pd.DataFrame()
for time in wu['Time']:
  print(time)
  temp_1 = pd.concat([pd.DataFrame([time]*sample.shape[0], columns = ['Time']), sample], axis = 1)
  #
  temp = pd.concat([temp, temp_1], axis = 0, ignore_index = True)
  del temp_1
  clear_output()
del sample

# %%
temp = pd.merge(temp, wu, left_on = 'Time', right_on = 'Time')
print('temp_shape : ', temp.shape)
#temp
# Out:
# temp_shape :  (1249560, 14)

# %%
data = data.merge(temp, on = ['Time', 'Scenario', 'Sources', 'Interchange Flows', 'Sector'], how = 'outer')
print('data_shape : ', data.shape)
# Shift column 'Price (CAD $/GJ)' to first position
last_column = data.pop('Price (CAD $/GJ)')
# Insert column using insert(position,column_name,first_column) function
data.insert(data.shape[1], 'Price (CAD $/GJ)', last_column)
#
#data = data[data['Time']>='2018-12-31']
#print('data_shape : ', data.shape)
#data.reset_index(inplace = True, drop = True)
#
data.head(5)
# Out:
# data_shape :  (1249740, 23)
#           Scenario                       Sources        Time  \
# 0  Global Net-zero  Coal, Coke and Coke Oven Gas  2004-12-01
# 1  Global Net-zero  Coal, Coke and Coke Oven Gas  2004-12-01
# 2  Global Net-zero  Coal, Coke and Coke Oven Gas  2004-12-01
# 3  Global Net-zero  Coal, Coke and Coke Oven Gas  2004-12-01
# 4  Global Net-zero  Coal, Coke and Coke Oven Gas  2004-12-01
#
#    Primary Demand - Petajoules  Electricity Generation - (GWh)  \
# 0                       547.86                        43581.07
# 1                       547.86                        43581.07
# 2                       547.86                        43581.07
# 3                       547.86                        43581.07
# 4                       547.86                        43581.07
#
#    Electricity Capacity - (GWh)          Interchange Flows  Interchange (GWh)  \
# 0                        5696.0   Interprovincial In-Flows            1740.06
# 1                        5696.0   Interprovincial In-Flows            1740.06
# 2                        5696.0   Interprovincial In-Flows            1740.06
# 3                        5696.0  Interprovincial Out-Flows            1198.17
# 4                        5696.0  Interprovincial Out-Flows            1198.17
#
#         Sector  End-Use Demand (PetaJoules)  ...  Temp_Max (°F)  \
# 0  Residential                        27.97  ...            NaN
# 1   Commercial                        45.73  ...            NaN
# 2   Industrial                       137.60  ...            NaN
# 3  Residential                        27.97  ...            NaN
# 4   Commercial                        45.73  ...            NaN
#
#    Temp_Avg (°F)  Temp_Min (°F)  Hum_Max (%)  Hum_Avg (%)  Hum_Min (%)  \
# 0            NaN            NaN          NaN          NaN          NaN
# 1            NaN            NaN          NaN          NaN          NaN
# 2            NaN            NaN          NaN          NaN          NaN
# 3            NaN            NaN          NaN          NaN          NaN
# 4            NaN            NaN          NaN          NaN          NaN
#
#    Wind_Speed_Max (mph)  Wind_Speed_Avg (mph)  Wind_Speed_Min (mph)  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    Price (CAD $/GJ)
# 0             33.21
# 1             26.44
# 2             21.92
# 3             33.21
# 4             26.44
#
# [5 rows x 23 columns]

# %%
data.isnull().sum()
# Out:
# Scenario                                              0
# Sources                                               0
# Time                                                  0
# Primary Demand - Petajoules                     1246140
# Electricity Generation - (GWh)                  1246140
# Electricity Capacity - (GWh)                    1246140
# Interchange Flows                                     0
# Interchange (GWh)                               1246140
# Sector                                                0
# End-Use Demand (PetaJoules)                     1246140
# GHG Emmisions (KTons_CO2_Equivalent)            1246140
# Population                                      1246140
# Real Gross Domestic Product ($2012 Millions)    1246140
# Temp_Max (°F)                                       180
# Temp_Avg (°F)                                       180
# Temp_Min (°F)                                       180
# Hum_Max (%)                                         180
# Hum_Avg (%)                                         180
# Hum_Min (%)                                         180
# Wind_Speed_Max (mph)                                180
# Wind_Speed_Avg (mph)                                180
# Wind_Speed_Min (mph)                                180
# Price (CAD $/GJ)                                1246140
# dtype: int64

# %% [markdown]
# ## **4 - Filling Missing Values - Daily Basis**

# %% [markdown]
# #### **5.1 - Applying KNN Imputer**

# %%
num_cols = data.select_dtypes(include = [np.number, 'period[D]','float64']).columns.tolist()
data_num = data[num_cols]

# %%
#num_cols

# %% [markdown]
# from sklearn.impute import KNNImputer
# mae_ = []
# for i in range(1,40):            # i: k_value for nearest-neighbors
#     print('i =', i)
#     imputer = KNNImputer(n_neighbors = i, weights='uniform', metric='nan_euclidean')
#     imputer.fit(data_num.iloc[:,1:])
#     temp_ = imputer.transform(data_num.iloc[:,1:])
#     temp_ = pd.DataFrame(temp_)
#     mae_.append(abs(data.iloc[:,-1].std(axis=0, skipna=True)- temp_.iloc[:,-1].std(axis=0, skipna=True)))
#     clear_output()

# %% [markdown]
# plt.figure(figsize = (15,5))
# plt.plot([i for i in range(1,len(mae_)+1)], mae_, color='blue', linestyle='dashed',
#          marker='o', markerfacecolor='red', markersize=10)
# Naming the x-axis, y-axis and the whole graph
# plt.xlabel("k_value")
# plt.ylabel('MAE')
# plt.show()

# %%
from sklearn.impute import KNNImputer
# define imputer
imputer = KNNImputer(n_neighbors = 4, weights='uniform', metric='nan_euclidean')

# %%
new_df = pd.DataFrame()
for scenario in data['Scenario'].unique():
    for source in data['Sources'].unique():
        for sector in data['Sector'].unique():
            for flow in data['Interchange Flows'].unique():
                df_ = data[(data['Scenario'] == scenario) & (data['Sources'] == source) & (data['Sector'] == sector) & (data['Interchange Flows'] == flow)]
                data_num = df_[num_cols]
                imputer.fit(data_num.iloc[:,1:])
                # transform the dataset
                data_num.iloc[:,1:] = imputer.transform(data_num.iloc[:,1:])
                data_num = pd.DataFrame(data_num, columns = num_cols)
                for col in num_cols:
                    df_[col] = data_num[col]
                #
                new_df = pd.concat([new_df, df_], axis = 0, ignore_index = True)

# %%
new_df.isnull().sum()
# Out:
# Scenario                                        0
# Sources                                         0
# Time                                            0
# Primary Demand - Petajoules                     0
# Electricity Generation - (GWh)                  0
# Electricity Capacity - (GWh)                    0
# Interchange Flows                               0
# Interchange (GWh)                               0
# Sector                                          0
# End-Use Demand (PetaJoules)                     0
# GHG Emmisions (KTons_CO2_Equivalent)            0
# Population                                      0
# Real Gross Domestic Product ($2012 Millions)    0
# Temp_Max (°F)                                   0
# Temp_Avg (°F)                                   0
# Temp_Min (°F)                                   0
# Hum_Max (%)                                     0
# Hum_Avg (%)                                     0
# Hum_Min (%)                                     0
# Wind_Speed_Max (mph)                            0
# Wind_Speed_Avg (mph)                            0
# Wind_Speed_Min (mph)                            0
# Price (CAD $/GJ)                                0
# dtype: int64

# %% [markdown]
# #### **5.2 - Visualizations**

# %%
data.sort_values(by = 'Time', axis = 0, ascending = True, inplace = True)
new_df.sort_values(by = 'Time', axis = 0, ascending = True, inplace = True)

# %%
vv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-09dbdbc7f6cd> in <cell line: 1>()
# ----> 1 ss
#
# NameError: name 'ss' is not defined

# %%
for source in data['Sources'].unique():
    for flow in data['Interchange Flows'].unique():
        for sector in data['Sector'].unique():
          df_ = new_df[(new_df['Sector'] == sector) & (new_df['Scenario'] == 'Current Measures') & (new_df['Sources'] == source) & (new_df['Interchange Flows'] == flow)]
          plt.figure(figsize=(15,5))
          plt.plot(pd.to_datetime(data['Time'].astype(str)), data['Price (CAD $/GJ)'], color='b', label = 'Raw')
          plt.plot(pd.to_datetime(df_['Time'].astype(str)), df_['Price (CAD $/GJ)'], color='k', linestyle = 'dashed', label = 'Imputed')
          # Naming the x-axis, y-axis and the whole graph
          plt.xlabel("timestamp")
          plt.ylabel('Price (CAD $/GJ)')
          plt.title(source + ' - ' + flow + ' - ' + sector)
          #
          plt.legend()
          plt.show()
          print('\n')

# %%
new_df[new_df['Time']>='2014-01-01'].shape
# Out:
# (657180, 23)

# %%
new_df[new_df['Time']>='2014-01-01'].to_excel('Alberta_EP_Daily_Macro_Econ_.xlsx', index = False, freeze_panes=(1,0))
files.download('Alberta_EP_Daily_Macro_Econ_.xlsx')
